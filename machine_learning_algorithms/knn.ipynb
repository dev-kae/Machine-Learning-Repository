# %%
import numpy as np
from matplotlib.pyplot import plot as plt
from algorithms.knn import KNN
import matplotlib.pylab as plt

# Localização dos valores
X_train = np.array([[1, 2], [2, 3], [3, 4], [6, 7], [7, 8], [8, 9]])
# Labels
y_train = np.array(['cachorro', 'cachorro', 'cachorro', 'gato', 'gato', 'gato'])
# Localização dos valores a serem classificados
X_test = np.array([[2, 2], [7, 5]])


matrix = np.column_stack((X_train, y_train))

# Gráfico de dispersão dos dados de treino
plt.scatter(X_train[:, 0], X_train[:, 1], color='green', label='Treino')

# Gráfico de dispersão dos dados de teste
plt.scatter(X_test[:, 0], X_test[:, 1], color='red', label='Teste')

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.title('Gráfico de Dispersão')

# Mostrar o gráfico
plt.show()

# %%
knn = KNN(k=3)
knn.fit(X_train, y_train)

predictions = knn.predict(X_test)
print(predictions)
# Out:
# ['cachorro' 'gato']
